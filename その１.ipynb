# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2. Read the computer hardware dataset from UCI and assign it to a variable called `hw_df`.

# %% [markdown]
# ### 3. Display the first 5 rows of the dataset.

# %% [markdown]
# ### 4. Get the summary information of the dataset using an appropriate method.

# %% [markdown]
# ### 5. Generate descriptive statistics of the dataset.

# %% [markdown]
# ### 6. How many unique vendors are present in the dataset?

# %% [markdown]
# ### 7. List all the unique vendor names.

# %% [markdown]
# ### 8. Set the column 'Model name' as the index of `hw_df`.

# %% [markdown]
# ### 9. List all the column names in the dataset.

# %% [markdown]
# ### 10. Select the 'MYCT' and 'MMIN' columns using `.loc`.

# %% [markdown]
# ### 11. Select the 'CACH' and 'CHMIN' columns using `.iloc`.

# %% [markdown]
# ### 12. Filter and display models where 'MYCT' is less than 30 nanoseconds.

# %% [markdown]
# ### 13. Which model has the highest 'PRP' (Published Relative Performance)?

# %% [markdown]
# ### 14. How many models are produced by the vendor 'amdahl'?

# %% [markdown]
# ### 15. Add a new column 'Memory Range' that calculates the difference between 'MMAX' and 'MMIN'.

# %% [markdown]
# ### 17. Create a new DataFrame `vendor_df` containing only 'VendorName' and 'PRP' columns.

# %% [markdown]
# ### 18. Remove all rows from `vendor_df` where 'PRP' is less than 200.

# %% [markdown]
# ### 19. Save `vendor_df` to a new CSV file named 'vendor_performance.csv'.
