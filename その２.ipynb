# %% [markdown]
# #### 1. Import numpy, pandas, and seaborn libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### 2. Read the fertility.csv dataset and assign it to a variable called `fertility_df`

# %% [markdown]
# #### 3. Determine the number of rows and columns in the dataset

# %% [markdown]
# #### 4. Get the names of the columns

# %% [markdown]
# #### 5. Check data types of each column

# %% [markdown]
# #### 6. List statistical information of all numerical columns

# %% [markdown]
# #### 7. Print all values in the "alcohol" column

# %% [markdown]
# #### 8. Count how many unique values are in the "smoking" column and print them

# %% [markdown]
# #### 9. Count the occurrences of each unique value in the "diagnosis" column

# %% [markdown]
# #### 10. Sort the dataset based on the "age" column in ascending order

# %% [markdown]
# #### 11. Filter the dataset to include rows where 'hrs_sitting' is greater than 0.5 and 'smoking' equals 1

# %% [markdown]
# #### 12. Calculate the correlation matrix of the numerical features

# %% [markdown]
# #### 13. Group the dataset by 'diagnosis' and find the mean of the 'age' column for each group

# %% [markdown]
# #### 16. Find and display the rows where the 'diagnosis' is 'N' and 'smoking' is 1

# %% [markdown]
# #### 17. Line plot of 'age' over 'hrs_sitting'

# %% [markdown]
# ### 18. Plot a histogram using seaborn for 'alcohol'
# Requirements:
#     - The number of bins is 10
#     - Remove the top and right spines

# %% [markdown]
# ![image.png](attachment:image.png)
