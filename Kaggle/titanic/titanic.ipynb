# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from sklearn.preprocessing  import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
import optuna
import mlflow
import mlflow.sklearn
import joblib

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#Read data set
data = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

#Store train data size
ntrain = data.shape[0]

print(f"data shape {data.shape} ")
print(f"test shape {test.shape} ")

#Combine both data for smooth data cleaning
all_data = pd.concat([data, test], axis=0).reset_index(drop=True)

#remove target label from combibed data 
all_data = all_data.drop("Survived", axis=1)

print(f"all_data shape {all_data.shape}")
# Out:
# data shape (891, 12)
# test shape (418, 11)
# all_data shape (1309, 11)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
print(data.describe(include="all"))
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
print("Proportion of Survived", data["Survived"].value_counts())
# Out:
# Proportion of Survived Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#Check missing values
missing_columns  = (all_data.isnull().sum() /len(all_data)).sort_values(ascending=False)
print(f"Before removing high missing rate \n {missing_columns}")
print("-"*40)

#Remove colums("Cabin") in wchih more than 40% of data is missing value
#Remove "Ticket" column because it doesn't include any info   
try:
    all_data.drop(["Cabin", "Ticket"], axis=1, inplace=True)
except KeyError:
    print("Columns already dropped.")
print(f"After removing high missing rate \n {all_data.isnull().sum().sort_values(ascending=False)}")
# Out:
# Before removing high missing rate
#  Cabin          0.774637
# Age            0.200917
# Embarked       0.001528
# Fare           0.000764
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# dtype: float64
# ----------------------------------------
# After removing high missing rate
#  Age            263
# Embarked         2
# Fare             1
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# dtype: int64

# %%
#About age column

#Visualize
sns.kdeplot(data= all_data, x= "Age", hue="Pclass")
plt.show()

#It shows that there is a age-mean diffrence between Plcass

#Fill age missing values by Plclass
all_data["Age"] = all_data.groupby("Pclass")["Age"].transform(lambda x:x.fillna(x.mean()))
print(f"Number of missing valued after filling it {all_data["Age"].isna().sum()}")

#Fill "Embarked" missing values by mode
all_data["Embarked"] = all_data["Embarked"].fillna(all_data["Embarked"].mode()[0])

#Fill "Fare" missing values by median
all_data["Fare"] = all_data["Fare"].fillna(all_data["Fare"].median())
# Out:
# Number of missing valued after filling it 0

# %%
#Add new features
#"FamilySize" denotes how mamy relatives there were in Titanic 
all_data["FamilySize"] = all_data["SibSp"] + all_data["Parch"] + 1

#"IsAlone" denotes if that passernger was alone or not (yes/1 is alone) 
all_data["IsAlone"] = 1 
all_data["IsAlone"].loc[all_data["FamilySize"] >1] = 0

#"Title" denotes "Mr","Mrs" etc 
all_data["Title"] = all_data["Name"].str.split(",", expand=True)[1].str.split(".", expand=True)[0]
# Out:
# C:\Users\thosa\AppData\Local\Temp\ipykernel_11244\4040335376.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data["IsAlone"].loc[all_data["FamilySize"] >1] = 0

# %%
#Chage small portion of titile to "others"
title_names  = (all_data["Title"].value_counts() < 10)
all_data["Title"] = all_data["Title"].apply(lambda x: "Misc" if title_names.loc[x] == True else x)
print(all_data["Title"].value_counts())
# Out:
# Title
#  Mr        757
#  Miss      260
#  Mrs       197
#  Master     61
# Misc        34
# Name: count, dtype: int64

# %%
#categorical data
categorical_data = all_data.select_dtypes("object")

for column in categorical_data.columns:
  contingency_table = pd.crosstab(data["Survived"], categorical_data[column])
  print(column)
  # Chi-Squre test
  chi2, p, dof, expected = chi2_contingency(contingency_table)
  print(f"Chi-square: {chi2}, p-value: {p}")

#The result indicates that　"Plcass"、"Sex","Embarked","Title" are related to "Survived"
# Out:
# Name
# Chi-square: 891.0, p-value: 0.484248151973633
# Sex
# Chi-square: 260.71702016732104, p-value: 1.1973570627755645e-58
# Embarked
# Chi-square: 25.964452881874784, p-value: 2.3008626481449577e-06
# Title
# Chi-square: 283.3115089621979, p-value: 4.305036064730923e-60

# %%
#numerical data 
plt.figure(figsize=(10,10))
numerical_data = data.select_dtypes(np.number)
sns.heatmap(numerical_data.corr(), annot=True)
plt.show()

# %%
#Extract essential features
extracted_df = all_data[["PassengerId","Pclass","Sex","Embarked", "FamilySize", "Age","IsAlone", "Title","Fare"]]
print(f"extracted_df {extracted_df.shape}")
print(extracted_df.head())
# Out:
# extracted_df (1309, 9)
#    PassengerId  Pclass     Sex Embarked  FamilySize   Age  IsAlone  Title  \
# 0            1       3    male        S           2  22.0        0     Mr
# 1            2       1  female        C           2  38.0        0    Mrs
# 2            3       3  female        S           1  26.0        1   Miss
# 3            4       1  female        S           2  35.0        0    Mrs
# 4            5       3    male        S           1  35.0        1     Mr
#
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
#Standalized numerical data 
std_extracted_df = extracted_df.copy()
Std = StandardScaler()
std_extracted_df["Age"] = Std.fit_transform(std_extracted_df[["Age"]])
std_extracted_df["Fare"] = Std.fit_transform(std_extracted_df[["Fare"]])
std_extracted_df.head()
# Out:
#    PassengerId  Pclass     Sex Embarked  FamilySize       Age  IsAlone  Title  \
# 0            1       3    male        S           2 -0.559957        0     Mr
# 1            2       1  female        C           2  0.659292        0    Mrs
# 2            3       3  female        S           1 -0.255145        1   Miss
# 3            4       1  female        S           2  0.430683        0    Mrs
# 4            5       3    male        S           1  0.430683        1     Mr
#
#        Fare
# 0 -0.503291
# 1  0.734744
# 2 -0.490240
# 3  0.383183
# 4 -0.487824

# %%
#One-Hot encoding
std_extracted_df = pd.get_dummies(data=std_extracted_df, columns=["Sex","Embarked","Title"])
std_extracted_df.head()
# Out:
#    PassengerId  Pclass  FamilySize       Age  IsAlone      Fare  Sex_female  \
# 0            1       3           2 -0.559957        0 -0.503291       False
# 1            2       1           2  0.659292        0  0.734744        True
# 2            3       3           1 -0.255145        1 -0.490240        True
# 3            4       1           2  0.430683        0  0.383183        True
# 4            5       3           1  0.430683        1 -0.487824       False
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S  Title_ Master  Title_ Miss  \
# 0      True       False       False        True          False        False
# 1     False        True       False       False          False        False
# 2     False       False       False        True          False         True
# 3     False       False       False        True          False        False
# 4      True       False       False        True          False        False
#
#    Title_ Mr  Title_ Mrs  Title_Misc
# 0       True       False       False
# 1      False        True       False
# 2      False       False       False
# 3      False        True       False
# 4       True       False       False

# %%
#Split all_data into train and test data 
train = std_extracted_df[:ntrain]
y = data["Survived"]
train = train.drop("PassengerId", axis=1)

test = std_extracted_df[ntrain:]
PassengerId = test["PassengerId"]
test = test.drop("PassengerId", axis=1)

print(f"train shpae {train.shape}")
print(f"test shpae {test.shape}")

test.to_csv("preprocessed_test.csv")
# Out:
# train shpae (891, 15)
# test shpae (418, 15)

# %%
#Split train data into train and validation data
X_train, X_test, y_train, y_test = train_test_split(train, y, test_size=0.2, random_state=42)

# %%
#Execute Grid Serach to find better Algorithm and hyper parmeters
models = {
    "DecisionTree": (DecisionTreeClassifier(random_state=42), {'max_depth': [3,4, 5, 10], "min_samples_split":[2,3,4,5],"criterion":["gini","entropy"]}),
    "RandomForest": (RandomForestClassifier(random_state=42), {'max_depth': [3,4, 5, 10],'n_estimators': [10, 50, 100]}),
    "Bagging":(BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=4), random_state=42), {"n_estimators":[10,50,100]}),
    "Boosting":(GradientBoostingClassifier(random_state=42), {"n_estimators":[10,50,100], "learning_rate":[0.001, 0.01, 0.1]})
}

for name, (model, param_grid) in models.items():
    grid_search = GridSearchCV(model, param_grid, cv=5)
    grid_search.fit(X_train, y_train)
    print(f"Model: {name}")
    print(f"Best Parameters: {grid_search.best_params_}")
    print(f"Best Cross-validation Score: {grid_search.best_score_:.2f}")
    print("-"*40)

#From this execution 
# Model: RandomForest
# Best Parameters: {'max_depth': 5, 'n_estimators': 10}
# Best Cross-validation Score: 0.84
# performed the best
# Out:
# Model: DecisionTree
# Best Parameters: {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 2}
# Best Cross-validation Score: 0.82
# ----------------------------------------
# Model: RandomForest
# Best Parameters: {'max_depth': 5, 'n_estimators': 10}
# Best Cross-validation Score: 0.84
# ----------------------------------------
# Model: Bagging
# Best Parameters: {'n_estimators': 50}
# Best Cross-validation Score: 0.82
# ----------------------------------------
# Model: Boosting
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 100}
# Best Cross-validation Score: 0.82
# ----------------------------------------

# %%
mlflow.set_experiment("optuna_model_selection")
def objective(trial):
    model_name = trial.suggest_categorical("model", ["DecisionTree", "RandomForest", "Bagging", "Boosting"])

    # モデルとハイパーパラメータの提案
    if model_name == "DecisionTree":
        max_depth = trial.suggest_int("max_depth", 3, 10)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 5)
        criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
        model = DecisionTreeClassifier(max_depth=max_depth, min_samples_split=min_samples_split,
                                        criterion=criterion, random_state=42)
        params = {
            "model": model_name,
            "max_depth": max_depth,
            "min_samples_split": min_samples_split,
            "criterion": criterion
        }

    elif model_name == "RandomForest":
        max_depth = trial.suggest_int("max_depth", 3, 10)
        n_estimators = trial.suggest_categorical("n_estimators", [10, 50, 100])
        model = RandomForestClassifier(max_depth=max_depth, n_estimators=n_estimators, random_state=42)
        params = {
            "model": model_name,
            "max_depth": max_depth,
            "n_estimators": n_estimators
        }

    elif model_name == "Bagging":
        n_estimators = trial.suggest_categorical("n_estimators", [10, 50, 100])
        base_estimator = DecisionTreeClassifier(max_depth=4)
        model = BaggingClassifier(estimator=base_estimator, n_estimators=n_estimators, random_state=42)
        params = {
            "model": model_name,
            "n_estimators": n_estimators
        }

    else:  # Boosting
        n_estimators = trial.suggest_categorical("n_estimators", [10, 50, 100])
        learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.01, 0.1])
        model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, random_state=42)
        params = {
            "model": model_name,
            "n_estimators": n_estimators,
            "learning_rate": learning_rate
        }

    # クロスバリデーションで精度評価
    score = cross_val_score(model, X_train, y_train, cv=5, scoring="accuracy").mean()

    # MLflowにログ
    with mlflow.start_run():
         mlflow.log_params(params)
         mlflow.log_metric("accuracy", score)
         joblib.dump(model, "model.pkl")
         mlflow.log_artifact("model.pkl")

    return score


# 最適化
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

# 結果表示
print("Best Model and Parameters:")
print(study.best_params)
print(f"Best CV Accuracy: {study.best_value:.4f}")
# Out:
# [I 2025-06-18 17:29:43,153] A new study created in memory with name: no-name-0c7dc196-bb25-4ea6-bef1-851d9e8a04d1
# [I 2025-06-18 17:29:43,518] Trial 0 finished with value: 0.8159657244164287 and parameters: {'model': 'DecisionTree', 'max_depth': 6, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8159657244164287.
# [I 2025-06-18 17:29:43,726] Trial 1 finished with value: 0.8075248694967005 and parameters: {'model': 'RandomForest', 'max_depth': 10, 'n_estimators': 10}. Best is trial 0 with value: 0.8159657244164287.
# [I 2025-06-18 17:29:43,977] Trial 2 finished with value: 0.8202009258347285 and parameters: {'model': 'RandomForest', 'max_depth': 8, 'n_estimators': 10}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:44,184] Trial 3 finished with value: 0.8202009258347285 and parameters: {'model': 'RandomForest', 'max_depth': 8, 'n_estimators': 10}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:44,669] Trial 4 finished with value: 0.8145375751009555 and parameters: {'model': 'Boosting', 'n_estimators': 50, 'learning_rate': 0.1}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:44,996] Trial 5 finished with value: 0.8145375751009555 and parameters: {'model': 'Boosting', 'n_estimators': 50, 'learning_rate': 0.1}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:45,865] Trial 6 finished with value: 0.8159657244164287 and parameters: {'model': 'Boosting', 'n_estimators': 100, 'learning_rate': 0.1}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:46,059] Trial 7 finished with value: 0.796395154141633 and parameters: {'model': 'DecisionTree', 'max_depth': 10, 'min_samples_split': 3, 'criterion': 'entropy'}. Best is trial 2 with value: 0.8202009258347285.
# [I 2025-06-18 17:29:47,005] Trial 8 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:47,160] Trial 9 finished with value: 0.8047375160051216 and parameters: {'model': 'DecisionTree', 'max_depth': 4, 'min_samples_split': 4, 'criterion': 'gini'}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:47,886] Trial 10 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:48,542] Trial 11 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:49,148] Trial 12 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:49,673] Trial 13 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:50,616] Trial 14 finished with value: 0.8187530779080074 and parameters: {'model': 'Bagging', 'n_estimators': 100}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:51,194] Trial 15 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:51,829] Trial 16 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:52,498] Trial 17 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:53,476] Trial 18 finished with value: 0.8187530779080074 and parameters: {'model': 'Bagging', 'n_estimators': 100}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:54,031] Trial 19 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:54,601] Trial 20 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:55,136] Trial 21 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:55,636] Trial 22 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:56,108] Trial 23 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:56,581] Trial 24 finished with value: 0.8215601300108343 and parameters: {'model': 'Bagging', 'n_estimators': 50}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:56,807] Trial 25 finished with value: 0.8131685216192258 and parameters: {'model': 'Bagging', 'n_estimators': 10}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:56,962] Trial 26 finished with value: 0.817374175120654 and parameters: {'model': 'DecisionTree', 'max_depth': 3, 'min_samples_split': 5, 'criterion': 'gini'}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:57,638] Trial 27 finished with value: 0.8145375751009553 and parameters: {'model': 'Boosting', 'n_estimators': 100, 'learning_rate': 0.01}. Best is trial 8 with value: 0.8215601300108343.
# [I 2025-06-18 17:29:58,018] Trial 28 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:29:58,376] Trial 29 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:29:58,763] Trial 30 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:29:59,157] Trial 31 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:29:59,544] Trial 32 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:29:59,874] Trial 33 finished with value: 0.8342361863488623 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 50}. Best is trial 28 with value: 0.8342361863488623.
# [I 2025-06-18 17:30:00,059] Trial 34 finished with value: 0.8356446370530879 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:00,249] Trial 35 finished with value: 0.8272136314389835 and parameters: {'model': 'RandomForest', 'max_depth': 6, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:00,435] Trial 36 finished with value: 0.8272333300502315 and parameters: {'model': 'RandomForest', 'max_depth': 4, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:00,643] Trial 37 finished with value: 0.8272333300502315 and parameters: {'model': 'RandomForest', 'max_depth': 4, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:00,861] Trial 38 finished with value: 0.8272136314389835 and parameters: {'model': 'RandomForest', 'max_depth': 6, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:01,093] Trial 39 finished with value: 0.8356446370530879 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:01,326] Trial 40 finished with value: 0.8257854821235103 and parameters: {'model': 'RandomForest', 'max_depth': 7, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:01,559] Trial 41 finished with value: 0.8356446370530879 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:01,791] Trial 42 finished with value: 0.8356446370530879 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:02,032] Trial 43 finished with value: 0.8272333300502315 and parameters: {'model': 'RandomForest', 'max_depth': 4, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:02,256] Trial 44 finished with value: 0.8272136314389835 and parameters: {'model': 'RandomForest', 'max_depth': 6, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:02,473] Trial 45 finished with value: 0.8159558751108046 and parameters: {'model': 'RandomForest', 'max_depth': 3, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:02,707] Trial 46 finished with value: 0.8356446370530879 and parameters: {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:02,916] Trial 47 finished with value: 0.6235989362749926 and parameters: {'model': 'Boosting', 'n_estimators': 10, 'learning_rate': 0.001}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:03,079] Trial 48 finished with value: 0.8047375160051216 and parameters: {'model': 'DecisionTree', 'max_depth': 4, 'min_samples_split': 2, 'criterion': 'gini'}. Best is trial 34 with value: 0.8356446370530879.
# [I 2025-06-18 17:30:03,314] Trial 49 finished with value: 0.8272136314389835 and parameters: {'model': 'RandomForest', 'max_depth': 6, 'n_estimators': 10}. Best is trial 34 with value: 0.8356446370530879.
# Best Model and Parameters:
# {'model': 'RandomForest', 'max_depth': 5, 'n_estimators': 10}
# Best CV Accuracy: 0.8356

# %%
#Built a model by the best pefromance one
model = RandomForestClassifier(max_depth=5, n_estimators=100, random_state=6)
model.fit(X_train, y_train)
y_pred =model.predict(X_train)
print(f"Final Model Accuracy: {accuracy_score(y_train, y_pred):.2f}")
# Out:
# Final Model Accuracy: 0.85

# %%
#Formatlize result
compare_result = pd.DataFrame({
    'PassengerId': PassengerId,
    'Survived': model.predict(test)
})

# Save it to CSV file
compare_result.to_csv('submission.csv', index=False)

# %% [markdown]
# #API

# %%
from fastapi import FastAPI
from pydantic import BaseModel
from typing import List
from fastapi import FastAPI, Body
from pydantic import BaseModel
from typing import List
import pandas as pd

app = FastAPI()


class InputData(BaseModel):
    Pclass: int
    FamilySize: int
    Age: float
    IsAlone: int
    Fare: float
    Sex_female: bool
    Sex_male: bool
    Embarked_C: bool
    Embarked_Q: bool
    Embarked_S: bool
    Title_Master: bool
    Title_Miss: bool
    Title_Mr: bool
    Title_Mrs: bool
    Title_Misc: bool


class InputDataList(BaseModel):
    data: List[InputData]

@app.post("/predict")
def predict(input_data: InputDataList):
    df = pd.DataFrame([d.model_dump() for d in input_data.data])
     # 学習時の特徴量名にスペースを入れて合わせる
    rename_map = {
        "Title_Master": "Title_ Master",
        "Title_Miss": "Title_ Miss",
        "Title_Mr": "Title_ Mr",
        "Title_Mrs": "Title_ Mrs"
    }
    df.rename(columns=rename_map, inplace=True)
    preds = model.predict(df)
    return {"predictions": preds.tolist()}

# %%
import uvicorn
import nest_asyncio
nest_asyncio.apply()
uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [11244]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:59020 - "POST /predict HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [11244]

# %% [markdown]
# # Request body
#
# [
#   {
#     "Pclass": 3,
#     "FamilySize": 1,
#     "Age": 0.392581,
#     "IsAlone": 1,
#     "Fare": -0.492093,
#     "Sex_female": false,
#     "Sex_male": true,
#     "Embarked_C": false,
#     "Embarked_Q": true,
#     "Embarked_S": false,
#     "Title_ Master": false,
#     "Title_ Miss": false,
#     "Title_ Mr": true,
#     "Title_ Mrs": false,
#     "Title_Misc": false
#   },
#   {
#     "Pclass": 3,
#     "FamilySize": 2,
#     "Age": 1.345120,
#     "IsAlone": 0,
#     "Fare": -0.508125,
#     "Sex_female": true,
#     "Sex_male": false,
#     "Embarked_C": false,
#     "Embarked_Q": false,
#     "Embarked_S": true,
#     "Title_ Master": false,
#     "Title_ Miss": false,
#     "Title_ Mr": false,
#     "Title_ Mrs": true,
#     "Title_Misc": false
#   },
#   {
#     "Pclass": 2,
#     "FamilySize": 1,
#     "Age": 2.488165,
#     "IsAlone": 1,
#     "Fare": -0.456164,
#     "Sex_female": false,
#     "Sex_male": true,
#     "Embarked_C": false,
#     "Embarked_Q": true,
#     "Embarked_S": false,
#     "Title_ Master": false,
#     "Title_ Miss": false,
#     "Title_ Mr": true,
#     "Title_ Mrs": false,
#     "Title_Misc": false
#   },
#   {
#     "Pclass": 3,
#     "FamilySize": 1,
#     "Age": -0.178941,
#     "IsAlone": 1,
#     "Fare": -0.475981,
#     "Sex_female": false,
#     "Sex_male": true,
#     "Embarked_C": false,
#     "Embarked_Q": false,
#     "Embarked_S": true,
#     "Title_ Master": false,
#     "Title_ Miss": false,
#     "Title_ Mr": true,
#     "Title_ Mrs": false,
#     "Title_Misc": false
#   },
#   {
#     "Pclass": 3,
#     "FamilySize": 3,
#     "Age": -0.559957,
#     "IsAlone": 0,
#     "Fare": -0.405895,
#     "Sex_female": true,
#     "Sex_male": false,
#     "Embarked_C": false,
#     "Embarked_Q": false,
#     "Embarked_S": true,
#     "Title_ Master": false,
#     "Title_ Miss": false,
#     "Title_ Mr": false,
#     "Title_ Mrs": true,
#     "Title_Misc": false
#   }
# ]
